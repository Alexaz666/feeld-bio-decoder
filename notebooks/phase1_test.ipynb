# %%
import sys
import os
import json
import re

# %%
from get_text_pipeline import run_get_text_pipeline

# %%
run_get_text_pipeline("Mill")
# Out:
# [✓] Merged bio saved to: data/merged_bios/Mill_merged.json
# ...
